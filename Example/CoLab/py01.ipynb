# %% [markdown]
# <a href="https://colab.research.google.com/github/pokai-huang0828/2205-Final/blob/main/Example/CoLab/py01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Day1**

# %% [markdown]
# # Python Day 1 July 3th, 2022

# %%
# Check GPU information
# !nvidia-smi
# Out:
# Sun Jul  3 15:46:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# 下載字體並移至指定路徑
# !wget -O taipei_sans_tc_black.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

# !mv taipei_sans_tc_black.ttf /usr/local/lib/python3.7/dist-packages/matplotlib/mpl-data/fonts/ttf
# Out:
# --2022-07-03 16:16:12--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 142.251.10.100, 142.251.10.139, 142.251.10.138, ...
# Connecting to drive.google.com (drive.google.com)|142.251.10.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/vcsfd8tv4voiiiv0fm5unb4mcujm06i7/1656864900000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=ab25944d-90b6-4971-b09c-2a8e693c76ce [following]
# ...
# --2022-07-03 16:16:14--  https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/vcsfd8tv4voiiiv0fm5unb4mcujm06i7/1656864900000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=ab25944d-90b6-4971-b09c-2a8e693c76ce
# Resolving doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)... 142.250.4.132, 2404:6800:4003:c06::84
# ...

# %%
# 引用引用FontProperties
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt

# 自定義字體變數
myfont=FontProperties(fname=r'/usr/local/lib/python3.7/dist-packages/matplib/mpl-data/fonts/ttf/taipei_scans_tc_black.ttf')

# %% [markdown]
# # Type of Data

# %%
var1=20
print(type(var1))
var2=123.45
print(type(var2))
var3=True
print(type(var3))
var4='Hello'
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
a=5
print(id(a))
a=20
print(id(a))
a='test'
print(id(a))
# Out:
# 11256192
# 11256672
# 139724163908528

# %%
# sep=分界; end=結尾
print(4, 5, 6, sep='-', end='\n\n') 
print("Hello!! \nPOKAI")
# Out:
# 4-5-6
#
# Hello!!
# POKAI

# %%
# Variable 變數
userName="POKAI，HUANG"
print("My full name is: "+ userName)

# Type
name1="Kenny"
pi=3.14 
print(type(name1))
print(type(pi))
# Out:
# My full name is: POKAI，HUANG
# <class 'str'>
# <class 'float'>

# %%
baseSalary=25000
commission=1000
sales=18
pay=baseSalary+(commission*sales)

pay
# Out:
# 43000

# %% [markdown]
# # 數值運算

# %% [markdown]
# ![數值運算.png](data:image/png;base64,...)

# %%
a=3*6
b=9/5 # /運算為float(2進位)
c=10/5
d=9//5 # //運算為整數
e=3**4
f=9<<2
g=9>>2

print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
# Out:
# 18
# 1.8
# 2.0
# 1
# 81
# 36
# 2

# %% [markdown]
# # 賦值運算

# %% [markdown]
# ![賦值運算.png](data:image/png;base64,...)

# %%
a=8
a+=7
print(a)
a-=6
print(a)
a*=5
print(a)
a//=4
print(a)
a%=3
print(a)
a/=2
print(a)
a**=1
print(a)
# Out:
# 15
# 9
# 45
# 11
# 2
# 1.0
# 1.0

# %%
coin1=20
coin5=10
coin10=5
coin50=2
coin_total=coin50*50+coin10*10+coin5*15+coin1*1

print("硬幣金額為:", coin_total, "元")

bill100=3
bill200=2
bill500=1
bill1000=2
bill_total=(bill100+bill200*2+bill500*5+bill1000*10)*100

print("紙鈔金額為:", bill_total, "元")

print("總金額:", bill_total+coin_total, "元")
# Out:
# 硬幣金額為: 320 元
# 紙鈔金額為: 3200 元
# 總金額: 3520 元

# %%
c1, c2, c3 = 0, 25, 98

f1 = 9/5*c1+32
f2 = 9/5*c2+32
f3 = 9*c3//5+32

print("攝氏", c1, "度等於華氏", round(f1), '度')
print("攝氏", c2, "度等於華氏", int(f2), '度')
print("攝氏", c3, "度等於華氏", f3, '度')
# Out:
# 攝氏 0 度等於華氏 32 度
# 攝氏 25 度等於華氏 77 度
# 攝氏 98 度等於華氏 208 度

# %% [markdown]
# # 文字資料運算

# %%
print("Hello "+"POPO")
print("Hello "*3)

# int(), float() 字串轉換為數字
# str() 數字轉換為字串
# Out:
# Hello POPO
# Hello Hello Hello

# %%
# 字符轉換相加範例
x = 123
y = "456"

print(str(x)+" + "+y+" = "+str(x+int(y)))
# Out:
# 123 + 456 = 579

# %% [markdown]
# # 取得使用者資料input

# %%
temp = input('輸入溫度')
print(temp)
type(temp)

temp2 = input('輸入溫度')
print(temp2)
print(temp+temp2)

temp = int(temp)
temp2 = int(temp2)
print(temp+temp2)
# Out:
# 輸入溫度50
# 50
# 輸入溫度30
# 30
# 5030
# 80

# %% [markdown]
# # 資料格式化輸出

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i = 123
print('%5d' %i)
print('*%5d*' %i)
print('*%-5d*' %i)
print('*%05d*' %i)
# Out:
#   123
# *  123*
# *123  *
# *00123*

# %% [markdown]
# # In Class EX

# %%
# EX1
ch = int(input('請出入國文成績:'))
math = int(input('請輸入數學成績:'))
eng = int(input('請輸入英文成績:'))


total_scr = ch+math+eng
avg_scr = total_scr/3

print("總成績:", total_scr)
print("平均分數:%6.2f" %avg_scr)
# Out:
# 請出入國文成績:93
# 請輸入數學成績:87
# 請輸入英文成績:92
# 總成績: 272
# 平均分數: 90.67

# %%
# EX2
C = int(input("請輸入攝氏溫度:"))
F = C*9//5+32
print("換算華氏溫度為:", F, "度")
# Out:
# 請輸入攝氏溫度:35
# 換算華氏溫度為: 95 度

# %%
# EX3
weight = float(input("請輸入您的體重(kg):"))
height = float(input("請輸入您的身高(cm):"))
height /= 100

BMI = weight/height**2
print("您的BMI值為:", round(BMI,1))
# Out:
# 請輸入您的體重(kg):78
# 請輸入您的身高(cm):174
# 您的BMI值為: 25.8

# %%
K=3.316512315

print('%.2f' %K)
# Out:
# 3.32

# %% [markdown]
# # HW1

# %%
"""This is my first homework on python"""

schoolName="巨匠電腦"
studentName="PoKai"
className="Python AI 入門"
print(schoolName+"你好! 我現在上的課是:"+className)
print("我心情很好，所以等一下要說三次!!")
print(("這課程讓我很開心，"+studentName+"會繼續努力的! ")*3)
# Out:
# 巨匠電腦你好! 我現在上的課是:Python AI 入門
# 我心情很好，所以等一下要說三次!!
# 這課程讓我很開心，PoKai會繼續努力的! 這課程讓我很開心，PoKai會繼續努力的! 這課程讓我很開心，PoKai會繼續努力的!
